# %% [markdown]
# # Highly divisible triangular number
#
# > Problem 12
#
# The sequence of triangle numbers is generated by adding the natural numbers. So the 7th triangle number would be $1 + 2 + 3 + 4 + 5 + 6 + 7 = 28$.
# The first ten terms would be:
#
# $$ 1, 3, 6, 10, 15, 21, 28, 36, 45, 55, ...$$
#
# Let us list the factors of the first seven triangle numbers:
#
# ```
#  1: 1
#  3: 1,3
#  6: 1,2,3,6
# 10: 1,2,5,10
# 15: 1,3,5,15
# 21: 1,3,7,21
# 28: 1,2,4,7,14,28
# ```
#
# We can see that 28 is the first triangle number to have over five divisors.
#
# What is the value of the first triangle number to have over five hundred divisors?

# %%
def triagle_num1(n):
    sum = 0
    while n > 0:
        sum = sum + n
        n = n - 1
    return sum

def triagle_num(n):
    return n*(n+1)/2

def divisors(n):
    lst =[]
    i=1
    while True:
        if n%i==0: lst.append(i)
        if i>=n/2: lst.append(n); break
        i=i+1            
    return len(lst)
       
#for i in range(2100,2110):    
   
for i in range(1,11):
    j= int(i*(i+1)/2)
    if divisors(j) >= 1:
        print(i,j,divisors(j))
# Out:
# 1 1 2
# 2 3 2
# 3 6 4
# 4 10 4
# 5 15 4
# 6 21 4
# 7 28 6
# 8 36 9
# 9 45 6
# 10 55 4

# %%
     
#for i in range(2100,2110):    

for i in range(2110,10000):
    n= int(i*(i+1)/2)
    cnt = 0
    for j in range (1, int(n/2)+1):
        if n%j==0: cnt=cnt+1; 
        if j>=n/2+1: break
    if cnt+1 >=500:
        print(i,n,cnt+1)
# Out:
# 2110
# 2111
# 2112
# 2113
# 2114
# 2115
# 2116
# 2117
# 2118
# 2119
# 2120
# 2121
# 2122
# 2123
# 2124
# 2125
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\offho\Code\ProjectEuler\P0012.ipynb 셀 3 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/offho/Code/ProjectEuler/P0012.ipynb#ch0000002?line=5'>6</a> for j in range (1, int(n/2)+1):
#       <a href='vscode-notebook-cell:/c%3A/Users/offho/Code/ProjectEuler/P0012.ipynb#ch0000002?line=6'>7</a>     if n%j==0: cnt=cnt+1;
# ----> <a href='vscode-notebook-cell:/c%3A/Users/offho/Code/ProjectEuler/P0012.ipynb#ch0000002?line=7'>8</a>     if j>=n/2+1: break
#       <a href='vscode-notebook-cell:/c%3A/Users/offho/Code/ProjectEuler/P0012.ipynb#ch0000002?line=8'>9</a> if cnt+1 >=500:
#      <a href='vscode-notebook-cell:/c%3A/Users/offho/Code/ProjectEuler/P0012.ipynb#ch0000002?line=9'>10</a>     print(i,n,cnt+1)
#
# KeyboardInterrupt:
